# %%
from sklearn.datasets import fetch_20newsgroups


train = fetch_20newsgroups(subset="train", data_home="D:/fastaiDL/newsgroups")

# %%
import numpy as np


names = np.array(train.target_names)

# %%
from sklearn.feature_extraction import _stop_words
_stop_words.ENGLISH_STOP_WORDS

linear
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
# ...

# %%
import nltk
nltk.download('wordnet')

lm = nltk.stem.WordNetLemmatizer()
lm.lemmatize('')

porter =  nltk.stem.PorterStemmer()
porter.stem('looking')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 'look'

# %%
from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer


PorterStemmer().stem('univers')
# Out:
# 'univ'

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
matrix = vectorizer.fit_transform(train.data[:100])

# %%
 = vectorizer.get_feature_names_out()

# %%
# from scipy import linalg
# %time
from sklearn import decomposition
clf = decomposition.TruncatedSVD(10)
clf.fit_transform(matrix)
# x = vectorizer.vocabulary_
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# array([[ 8.29642894e+00, -3.58591602e+00, -2.61886579e+00,
#         -3.09752059e-01,  4.70975603e-01,  5.27653848e-01,
#         -1.23505126e+00,  1.88840888e-02, -1.19299049e-02,
#         -1.97620207e+00],
#        [ 6.57809271e+00, -1.61095305e+00, -1.26513777e-01,
#          8.36928858e-01, -5.17445652e-01, -1.67439576e-01,
#          1.24046897e+00,  1.83417795e+00, -3.78676592e-02,
#         -2.24099166e+00],
#        [ 2.54202195e+01, -5.27370488e+00, -3.22054885e+00,
#         -1.96767209e+00,  2.29448714e+00,  1.15827619e+00,
#         -4.77713532e-01, -2.63334225e+00,  1.49807541e+00,
#         -3.66425322e+00],
#        [ 5.18433498e+00, -2.20987943e+00, -2.04973856e+00,
#         -1.16168135e+00, -1.02501907e+00,  7.51022029e-01,
#         -8.61119667e-01, -9.12018513e-02, -7.37252984e-01,
#         -2.27210429e+00],
#        [ 9.87282705e+00, -3.81762053e+00, -2.76217659e+00,
# ...

# %%
clf.components_.shape
# Out:
# (10, 6547)

# %%
from fastai.data.external import URLs, untar_data


path = untar_data(URLs.IMDB_SAMPLE, data="D:/fastaiDL/IMDB_sample")

# %%
import pandas as pd


data = pd.read_csv('IMDB_sample/imdb_sample/texts.csv')

# %%
data

# %%
train_labels = data.loc[data['is_valid']==False,'label']
train_text = data.loc[data['is_valid']==False,'text']

# %%
from collections import Counter


x = Counter(train_text[0].split(' '))

# %%
q = ['a','b','c']

# %%
q[:2] = ['x','y']

# %%
'abc'[::-1]
# Out:
# 'cba'
